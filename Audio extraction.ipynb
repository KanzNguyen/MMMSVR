# %%
import os

# %%
folder_path = '/kaggle/input/d/seapanther/l25-segments'
output_dir = '/kaggle/working/'
for filename in os.listdir(folder_path):
        #if filename.startswith('L01') and filename.endswith('.mp4'):
        if filename.endswith('.mp4'):
            video_path = os.path.join(folder_path, filename) #/kaggle/input/segmented-videos-aic/L01_V019_258.0_307.0.mp4
            output_path = os.path.join(output_dir, filename) #/kaggle/working/L01_V019_258
            output_path = os.path.splitext(output_path)[0] + '.wav' #/kaggle/working/L01_V019_258.wav

            # !ffmpeg -i "{video_path}" -q:a 0 -map a "{output_path}"
